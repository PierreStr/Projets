# %% [markdown]
# # Description des noms de variables

# %% [markdown]
# | Géographie      |                    |
# |-----------------|--------------------|
# | Région          | GEO_region         |
# | Province        | GEO_province       |
# | Commune         | GEO_commune        |
# | Code REFNIS (communes)    | GEO_commune_REFNIS         |
# | Coordonnée X / Y| GEOM_coord_X(_Y)   |

# %% [markdown]
# | Date           |                    |
# |----------------|--------------------|
# | Année          | DT_annee           |
# | Mois           | DT_mois            |
# | Heure          | DT_heure           |

# %% [markdown]
# | Condition de l'accident |                    |
# |-------------------------|--------------------|
# | Lumière                 | COND_lumiere       |
# | Météo                   | COND_meteo         |
# | État de la route                   | COND_route         |
# | Agglomération           | COND_agglomeration  |
# | Carrefour               | COND_carrefour      |
# | Type route              | COND_type_route     |
# | Présence d'obstacles              | COND_obstacles     |
# | Largeur de la route              | COND_routes_largeur_cat     |
# | Densité du réseau à proximité              | COND_densité     |

# %% [markdown]
# | Situation               |                    |
# |-------------------------|--------------------|
# | État des victimes           | ACC_etat_victimes  |
# | Vehicule impliqué 1              | ACC_vehicule_1     |
# | Vehicule impliqué 2              | ACC_vehicule_2     |
# | Type de collision           | ACC_collision_type  |
# | Nom de l'autoroute (le cas échéan)             | ACC_nom_autoroute      |

# %% [markdown]
# | Population (par commune)               |                    |
# |-------------------------|--------------------|
# | Moyenne de l'age                     | P_age_moyen              |
# | Médianne de l'age                     | P_age_median              |
# | Pourcentage de mariés              | P_%_Marié       |
# | Pourcentage de célibataires              | P_%_Célibataire       |
# | Pourcentage de divorcés              | P_%_Divorcé       |
# | Pourcentage de veufs              | P_%_Veufs       |
# | Pourcentage d'hommes              | P_%_H       |
# | Pourcentage de femmes              | P_%_F       |

# %% [markdown]
# | Occupation (par commune)               |                    |
# |-------------------------|--------------------|
# | Superficie totale                     | OCC_Total              |
# | Pourcentage de *Nom du terrain*                     | OCC_% *Nom du terrain*              |

# %% [markdown]
# | Revenus (par commune)     |                    |
# |-----------------|--------------------|
# | Pourcentage de personnes non prises en compte          | REV_pourcentage_manquant         |
# | Revenu médian        | REV_median       |
# | Risque de pauvreté administrative         | REV_risque_pauvrete        |
